# %% [markdown]
# # IMPORTANDO LIBRERIAS

# %%
import pandas as pd

# %% [markdown]
# # IMPORTANDO EXCEL

# %%
##Es importante notar la codificación de nuestro archivo csv, pues si NO se encuentra codificado en UTF-8 -que es el default que python espera encontrar-
## nos va a arrojar un error de "encoding" por lo que tenemos que especificar con "encoding='latin-1'" la codificación del archivo
raw_data = pd.read_csv(r'C:\AQUI VA LA RUTA DE TU ARCHIVO\Database_Test1.csv', encoding='latin-1')
raw_data
# Out:
#        NOMBRE   APELLIDO              CIUDAD           ESTADO  \
# 0       Pedro     Garcia             Tijuana  Baja California
# 1        Paco  Rodriguez            Irapuato       Guanajuato
# 2        Luis   Gonzalez                León       Guanajuato
# 3   Francisco  Fernandez  Puebla de Zaragoza           Puebla
# 4      Javier      Lopez       Ciudad Juárez        Chihuahua
# ..        ...        ...                 ...              ...
# 95        Jim       Moya             Morelia        Michoacán
# 96  Alexander      Bravo             Tijuana  Baja California
# 97    Valeria      Soler            Irapuato       Guanajuato
# 98    Miranda   Gallardo                León       Guanajuato
# 99        NaN        NaN                 NaN              NaN
#
#            TIMESTAMP   CANAL_COMPRA       PRECIO      CONSUMO    SEXO
# 0   2023/03/01 09:30  Tienda_Fisica   $1,897.00     En tienda  Hombre
# 1   2023/03/02 00:45  Tienda_Fisica   $1,069.00     En tienda  Hombre
# ...
